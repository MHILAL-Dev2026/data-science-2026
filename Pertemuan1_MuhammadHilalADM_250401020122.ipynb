# %% [markdown]
# <a href="https://colab.research.google.com/github/MHILAL-Dev2026/data-science-2026/blob/main/Pertemuan1_MuhammadHilalADM_250401020122.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # PERTEMUAN 1 DATA SCIENCE
#
# ###    Nama : Muhammad Hilal AD
# ###    NIM  : 250401020122
# ###    Kelas: IF 405

# %%
# SEL 1: Output sederhana
print("Hello, Data Science!")
print("Selamat datang di mata kuliah Pengantar Data Science!")
# Out:
# Hello, Data Science!
# Selamat datang di mata kuliah Pengantar Data Science!

# %%
# SEL 2: Variabel dan tipe data dasar
nama      = "M Hilal ADM"               # String
angkatan  = 2026                        # Integer
ipk       = 3.85                        # Float
aktif     = True                        # Boolean
print(f"Nama        : {nama}")
print(f"Angkatan    : {angkatan}")
print(f"IPK         : {ipk}")
print(f"Aktif       : {aktif}")
# Out:
# Nama        : M Hilal ADM
# Angkatan    : 2026
# IPK         : 3.85
# Aktif       : True

# %%
# SEL 3: List dan perulangan
tools = ["Python", "Google Colab", "Jupyter Notebook", "GitHub"]
print("\nTools Data Science yang akan kita pelajari:")
for i, tool in enumerate(tools, 1):
    print(f" {i}. {tool}")
# Out:
# Tools Data Science yang akan kita pelajari:
#  1. Python
#  2. Google Colab
#  3. Jupyter Notebook
#  4. GitHub

# %%
# SEL 4: Fungsi sederhana
def perkenalan(nama, prodi, angkatan):
    """Fungsi untuk menampilkan perkenalan mahasiswa."""
    return f"Hai! Saya {nama} dari {prodi}, angkatan {angkatan}."

hasil = perkenalan("M Hilal ADM", "Informatika", 2026)
print(hasil)
# Out:
# Hai! Saya M Hilal ADM dari Informatika, angkatan 2026.

# %% [markdown]
# ## Kesimpulan Singkat Pertemuan 1
#
# **Apa yang dipelajari**
#
# 1. Dasar-dasar pemrograman Python untuk Data Science, meliputi output sederhana menggunakan print(), penggunaan variabel dan tipe data dasar (string, integer, float, boolean), struktur data list, perulangan dengan for, serta pembuatan dan pemanggilan fungsi.
# 2. Penggunaan beberapa tools yang umum digunakan dalam Data Science, seperti Python, Google Colab, Jupyter Notebook, dan GitHub.
#
# **Temuan Utama**
#
# 1. Python memungkinkan pengolahan data dan pembuatan program secara sederhana dan terstruktur.
# 2. Variabel dapat menyimpan berbagai jenis data yang berbeda sesuai kebutuhan.
# 3. Perulangan membantu menampilkan atau memproses data secara otomatis tanpa menulis kode berulang.
#
# **Keterbatasan / Pertanyaan yang Muncul**
#
# 1. Contoh yang diberikan masih bersifat dasar dan belum mencakup pengolahan data nyata menggunakan pustaka Data Science seperti Pandas, NumPy, atau Matplotlib.
